# %%
from get_data import GetData
import pandas as pd

# %%
Lambeth = GetData('lambeth')
print(Lambeth.get_local_authority_data('Information/MonitoringLocalAuthority/GroupName=London/Json'))
# Out:
# {'@LocalAuthorityCode': '22', '@LocalAuthorityName': 'Lambeth', '@LaCentreLatitude': '51.489112', '@LaCentreLongitude': '-0.11067', '@LaCentreLatitudeWGS84': '6708272.298688', '@LaCentreLongitudeWGS84': '-12319.728046', '@DateContractClosed': '', '@ContractClosed': '0', '@HomeURL': 'http://www.Lambeth.gov.uk'}

# %%
Hackney = GetData('hackney')
print(Hackney.get_local_authority_data('Information/MonitoringLocalAuthority/GroupName=London/Json'))
# Out:
# {'@LocalAuthorityCode': '12', '@LocalAuthorityName': 'Hackney', '@LaCentreLatitude': '51.545787', '@LaCentreLongitude': '-0.055418', '@LaCentreLatitudeWGS84': '6718410.935789', '@LaCentreLongitudeWGS84': '-6169.103541', '@DateContractClosed': '', '@ContractClosed': '0', '@HomeURL': 'http://www.Hackney.gov.uk'}

# %%
df_lambeth_2018 = Lambeth.get_pollution_data(22, 2018)

# %%
df_lambeth_2017 = Lambeth.get_pollution_data(22, 2017)
df_lambeth_2017
# Out:
#    species_code                 species_desc  \
# 0          DUST  PM10 (not reference equiv.)
# 1          DUST  PM10 (not reference equiv.)
# 2          DUST  PM10 (not reference equiv.)
# 3           NO2             Nitrogen Dioxide
# 4           NO2             Nitrogen Dioxide
# 5           NO2             Nitrogen Dioxide
# 6          PM10             PM10 Particulate
# 7          PM10             PM10 Particulate
# 8          PM10             PM10 Particulate
# 9          DUST  PM10 (not reference equiv.)
# 10         DUST  PM10 (not reference equiv.)
# 11         DUST  PM10 (not reference equiv.)
# 12          NO2             Nitrogen Dioxide
# 13          NO2             Nitrogen Dioxide
# 14          NO2             Nitrogen Dioxide
# 15         PM10             PM10 Particulate
# 16         PM10             PM10 Particulate
# 17         PM10             PM10 Particulate
# 18          SO2              Sulphur Dioxide
# 19          SO2              Sulphur Dioxide
# ...

# %%
df_lambeth_2016 = Lambeth.get_pollution_data(22, 2016)
df_lambeth_2016
# Out:
#    species_code                 species_desc  \
# 0          DUST  PM10 (not reference equiv.)
# 1          DUST  PM10 (not reference equiv.)
# 2          DUST  PM10 (not reference equiv.)
# 3           NO2             Nitrogen Dioxide
# 4           NO2             Nitrogen Dioxide
# 5           NO2             Nitrogen Dioxide
# 6          PM10             PM10 Particulate
# 7          PM10             PM10 Particulate
# 8          PM10             PM10 Particulate
# 9          DUST  PM10 (not reference equiv.)
# 10         DUST  PM10 (not reference equiv.)
# 11         DUST  PM10 (not reference equiv.)
# 12          NO2             Nitrogen Dioxide
# 13          NO2             Nitrogen Dioxide
# 14          NO2             Nitrogen Dioxide
# 15         PM10             PM10 Particulate
# 16         PM10             PM10 Particulate
# 17         PM10             PM10 Particulate
# 18          SO2              Sulphur Dioxide
# 19          SO2              Sulphur Dioxide
# ...

# %%
df_lambeth_2015 = Lambeth.get_pollution_data(22,2015)
df_lambeth_2014 = Lambeth.get_pollution_data(22,2014)
df_list_lambeth = [df_lambeth_2014, df_lambeth_2015, df_lambeth_2016, df_lambeth_2017, df_lambeth_2018]

# %%
df_pm10 = pd.DataFrame()
for df in df_list_lambeth:
    df_pm10 = df_pm10.append(df.loc[(df['species_code'] == 'PM10') & (df['objective_name']=='Capture Rate (%)')])
df_pm10
# Out:
#    species_code      species_desc    objective_name value  \
# 8          PM10  PM10 Particulate  Capture Rate (%)    75
# 21         PM10  PM10 Particulate  Capture Rate (%)    64
# 34         PM10  PM10 Particulate  Capture Rate (%)    46
# 8          PM10  PM10 Particulate  Capture Rate (%)    74
# 17         PM10  PM10 Particulate  Capture Rate (%)    89
# 30         PM10  PM10 Particulate  Capture Rate (%)    32
# 8          PM10  PM10 Particulate  Capture Rate (%)    93
# 17         PM10  PM10 Particulate  Capture Rate (%)    58
# 30         PM10  PM10 Particulate  Capture Rate (%)    28
# 8          PM10  PM10 Particulate  Capture Rate (%)    82
# 17         PM10  PM10 Particulate  Capture Rate (%)    94
# 30         PM10  PM10 Particulate  Capture Rate (%)    48
# 8          PM10  PM10 Particulate  Capture Rate (%)    62
# 17         PM10  PM10 Particulate  Capture Rate (%)    99
# 30         PM10  PM10 Particulate  Capture Rate (%)    99
#
# ...

# %%
df_hackney_2014 = Hackney.get_pollution_data(12,2014)
df_hackney_2015 = Hackney.get_pollution_data(12,2015)
df_hackney_2016 = Hackney.get_pollution_data(12,2016)
df_hackney_2017 = Hackney.get_pollution_data(12,2017)
df_hackney_2018 = Hackney.get_pollution_data(12,2018)
df_hackney_2014.head()
# Out:
#   species_code                 species_desc  \
# 0         DUST  PM10 (not reference equiv.)
# 1         DUST  PM10 (not reference equiv.)
# 2         DUST  PM10 (not reference equiv.)
# 3          NO2             Nitrogen Dioxide
# 4          NO2             Nitrogen Dioxide
#
#                                       objective_name value  \
# 0                         40 ug/m3 as an annual mean    31
# 1  50 ug/m3 as a 24 hour mean, not to be exceeded...    12
# 2                                   Capture Rate (%)   100
# 3  200 ug/m3 as a 1 hour mean, not to be exceeded...     2
# 4                         40 ug/m3 as an annual mean    67
#
#               site_name  year
# 0  Hackney - Old Street  2014
# 1  Hackney - Old Street  2014
# 2  Hackney - Old Street  2014
# 3  Hackney - Old Street  2014
# 4  Hackney - Old Street  2014

# %%
df_list_hackney = [df_hackney_2014, df_hackney_2015, df_hackney_2016, df_hackney_2017, df_hackney_2018]
Hackney.plot_pollution_by_species('PM10', df_list_hackney)

# %%
Hillingdon = GetData('hillingdon')
print(Hillingdon.get_local_authority_data('Information/MonitoringLocalAuthority/GroupName=London/Json'))
# Out:
# {'@LocalAuthorityCode': '17', '@LocalAuthorityName': 'Hillingdon', '@LaCentreLatitude': '51.533411', '@LaCentreLongitude': '-0.452568', '@LaCentreLatitudeWGS84': '6716195.906043', '@LaCentreLongitudeWGS84': '-50379.639309', '@DateContractClosed': '31/03/2011 00:00:00', '@ContractClosed': '1', '@HomeURL': 'http://www.Hillingdon.gov.uk'}

# %%
df_hillingdon_2014 = Hillingdon.get_pollution_data(17,2014)
df_hillingdon_2015 = Hillingdon.get_pollution_data(17,2015)
df_hillingdon_2016 = Hillingdon.get_pollution_data(17,2016)
df_hillingdon_2017 = Hillingdon.get_pollution_data(17,2017)
df_hillingdon_2018 = Hillingdon.get_pollution_data(17,2018)
df_hillingdon_2014.head()
# Out:
#   species_code      species_desc  \
# 0          NO2  Nitrogen Dioxide
# 1          NO2  Nitrogen Dioxide
# 2          NO2  Nitrogen Dioxide
# 3           O3             Ozone
# 4           O3             Ozone
#
#                                       objective_name value  \
# 0  200 ug/m3 as a 1 hour mean, not to be exceeded...     0
# 1                         40 ug/m3 as an annual mean    58
# 2                                   Capture Rate (%)    97
# 3  100 ug/m3 as an 8 hour mean, not to be exceede...     4
# 4                                   Capture Rate (%)    99
#
#                 site_name  year
# 0  Hillingdon - Keats Way  2014
# 1  Hillingdon - Keats Way  2014
# 2  Hillingdon - Keats Way  2014
# 3  Hillingdon - Keats Way  2014
# 4  Hillingdon - Keats Way  2014

# %%
df_list_hillingdon = [df_hillingdon_2014, df_hillingdon_2015, df_hillingdon_2015, df_hillingdon_2016, df_hillingdon_2017, df_hillingdon_2018]
Hillingdon.plot_pollution_by_species('PM10',df_list_hillingdon)

# %%
Lambeth.plot_pollution_by_species('PM10', df_list_lambeth)

# %%
# df_combined_councils = [df_hillingdon_2014, df_hillingdon_2015, df_hillingdon_2015, df_hillingdon_2016, df_hillingdon_2017, df_hillingdon_2018, df_lambeth_2014, df_lambeth_2015, df_lambeth_2016, df_lambeth_2017, df_lambeth_2018]
df_combined_councils = df_list_hackney+df_list_hillingdon+df_list_lambeth
Lambeth.plot_pollution_by_species('PM10', df_combined_councils)
