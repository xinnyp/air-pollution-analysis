# %%
from get_data import GetData

# %%
Lambeth = GetData('lambeth')
print(Lambeth.get_local_authority_data('Information/MonitoringLocalAuthority/GroupName=London/Json'))
# Out:
# {'@LocalAuthorityCode': '22', '@LocalAuthorityName': 'Lambeth', '@LaCentreLatitude': '51.489112', '@LaCentreLongitude': '-0.11067', '@LaCentreLatitudeWGS84': '6708272.298688', '@LaCentreLongitudeWGS84': '-12319.728046', '@DateContractClosed': '', '@ContractClosed': '0', '@HomeURL': 'http://www.Lambeth.gov.uk'}

# %%
df_lambeth = Lambeth.get_pollution_data(22, 2018)
df_lambeth.head(100)
# Out:
#    species_code                 species_desc  \
# 0          DUST  PM10 (not reference equiv.)
# 1          DUST  PM10 (not reference equiv.)
# 2          DUST  PM10 (not reference equiv.)
# 3           NO2             Nitrogen Dioxide
# 4           NO2             Nitrogen Dioxide
# 5           NO2             Nitrogen Dioxide
# 6          PM10             PM10 Particulate
# 7          PM10             PM10 Particulate
# 8          PM10             PM10 Particulate
# 9          DUST  PM10 (not reference equiv.)
# 10         DUST  PM10 (not reference equiv.)
# 11         DUST  PM10 (not reference equiv.)
# 12          NO2             Nitrogen Dioxide
# 13          NO2             Nitrogen Dioxide
# 14          NO2             Nitrogen Dioxide
# 15         PM10             PM10 Particulate
# 16         PM10             PM10 Particulate
# 17         PM10             PM10 Particulate
# 18          SO2              Sulphur Dioxide
# 19          SO2              Sulphur Dioxide
# ...

# %%
Hackney = GetData('HACKNEY')
print(Hackney.get_local_authority_data('Information/MonitoringLocalAuthority/GroupName=London/Json'))
# Out:
# {'@LocalAuthorityCode': '12', '@LocalAuthorityName': 'Hackney', '@LaCentreLatitude': '51.545787', '@LaCentreLongitude': '-0.055418', '@LaCentreLatitudeWGS84': '6718410.935789', '@LaCentreLongitudeWGS84': '-6169.103541', '@DateContractClosed': '', '@ContractClosed': '0', '@HomeURL': 'http://www.Hackney.gov.uk'}

# %%
df_hackney = Hackney.get_pollution_data(12, 2018)
print(df_hackney)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-9e71a83ad05b> in <module>
# ----> 1 df_hackney = Hackney.get_pollution_data(12, 2018)
#       2 print(df_hackney)
#
# ~/PycharmProjects/AirPoluutioonAnalysis/get_data.py in get_pollution_data(self, local_authority_id, year)
#      34                                      'site_name': []})
#      35         for item in json_data['SiteObjectives']['Site']:
# ---> 36             for part in item['Objective']:
#      37                 pollution_df = pollution_df.append({'species_code': part['@SpeciesCode'],
#      38                                                     'species_desc': part['@SpeciesDescription'],
#
# TypeError: string indices must be integers

# %%
Bexley = GetData('Bexley')
print(Bexley.get_local_authority_data('Information/MonitoringLocalAuthority/GroupName=London/Json'))
# Out:
# {'@LocalAuthorityCode': '3', '@LocalAuthorityName': 'Bexley', '@LaCentreLatitude': '51.441355', '@LaCentreLongitude': '0.14861', '@LaCentreLatitudeWGS84': '6699738.789844', '@LaCentreLongitudeWGS84': '16543.189527', '@DateContractClosed': '', '@ContractClosed': '0', '@HomeURL': 'http://www.Bexley.gov.uk'}

# %%
df_bexley = Bexley.get_pollution_data(3, 2018)
df_bexley.head()
# Out:
#   species_code                 species_desc  \
# 0         DUST  PM10 (not reference equiv.)
# 1         DUST  PM10 (not reference equiv.)
# 2         DUST  PM10 (not reference equiv.)
# 3          NO2             Nitrogen Dioxide
# 4          NO2             Nitrogen Dioxide
#
#                                       objective_name value  \
# 0                         40 ug/m3 as an annual mean    20
# 1  50 ug/m3 as a 24 hour mean, not to be exceeded...     3
# 2                                   Capture Rate (%)    99
# 3  200 ug/m3 as a 1 hour mean, not to be exceeded...     0
# 4                         40 ug/m3 as an annual mean    21
#
#                  site_name
# 0  Bexley - Belvedere West
# 1  Bexley - Belvedere West
# 2  Bexley - Belvedere West
# 3  Bexley - Belvedere West
# 4  Bexley - Belvedere West
