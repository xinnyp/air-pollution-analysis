# %%
from get_data import GetData
import pandas as pd

# %%
hackney = GetData('Hackney')
lambeth = GetData('lambeth')
westminter = GetData('westminster')
london = GetData('london')

# %%
locations_list = [hackney, lambeth, westminter]

# %%
id_list = []
for i in locations_list:
    authority_id = i.get_local_authority_data(get_id= True)
    id_list.append(authority_id)
print(id_list)
# Out:
# ['12', '22', '33']

# %%
london.get_daily_pollution_stats(id_list)
# Out:
#    species_code                               site_name air_quality_index  \
# 0           NO2                    Hackney - Old Street                 2
# 1            O3                    Hackney - Old Street                 3
# 2          PM10                    Hackney - Old Street                 3
# 3           NO2                  Lambeth - Brixton Road                 2
# 4          PM10                  Lambeth - Brixton Road                 3
# 5           NO2           Lambeth - Bondway Interchange                 2
# 6          PM10           Lambeth - Bondway Interchange                 4
# 7           SO2           Lambeth - Bondway Interchange                 1
# 8           NO2               Lambeth - Streatham Green                 1
# 9          PM10               Lambeth - Streatham Green                 2
# 10          NO2  Westminster - Ebury Street (Grosvenor)                 2
# 11          NO2           Westminster - Marylebone Road                 2
# 12           O3           Westminster - Marylebone Road                 2
# 13          SO2           Westminster - Marylebone Road                 1
# 14         PM10      Westminster - Marylebone Road FDMS                 3
# 15         PM25      Westminster - Marylebone Road FDMS                 3
# 16          NO2    Westminster - Strand (Northbank BID)                 2
# 17          NO2           Westminster - Horseferry Road                 1
# 18         PM10           Westminster - Horseferry Road                 2
# 19          NO2             Westminster - Oxford Street                 2
# 20         PM10             Westminster - Oxford Street                 3
# 21          NO2    Westminster - Buckingham Palace Road                 2
# 22          NO2        Westminster - Oxford Street East                 2
# 23         PM10        Westminster - Oxford Street East                 2
# 24          NO2          Westminster - Cavendish Square                 2
# 25         PM10          Westminster - Cavendish Square                 3
#
#    air_quality_band site_code
# 0               Low       HK6
# 1               Low       HK6
# 2               Low       HK6
# 3               Low       LB4
# 4               Low       LB4
# 5               Low       LB5
# 6          Moderate       LB5
# 7               Low       LB5
# 8               Low       LB6
# 9               Low       LB6
# 10              Low       GV1
# 11              Low       MY1
# 12              Low       MY1
# 13              Low       MY1
# 14              Low       MY7
# 15              Low       MY7
# 16              Low       NB1
# 17              Low       WM0
# 18              Low       WM0
# 19              Low       WM6
# 20              Low       WM6
# 21              Low       WMA
# 22              Low       WMB
# 23              Low       WMB
# 24              Low       WMC
# 25              Low       WMC
